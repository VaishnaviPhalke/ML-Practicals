# %% [markdown]
# Assignment 2: Perofrm the following operations using Python on the data sets. Compute and Display summary statistics for each feature available in the dataset(min,max,range,standard deviation,variance,percentile).Illustrate the feature distributions using histogram Data Cleaning, Data Integration, Data Transformation

# %%
import pandas as pd
import numpy as np
df = pd.read_csv('diabetes.csv')

# %%
df.head()
# Out:
#    Pregnant  Glucose  Diastolic_BP  Skin_Fold  Serum_Insulin   BMI  \
# 0         6    148.0          72.0       35.0            NaN  33.6
# 1         1     85.0          66.0       29.0            NaN  26.6
# 2         8    183.0          64.0        NaN            NaN  23.3
# 3         1     89.0          66.0       23.0           94.0  28.1
# 4         0    137.0          40.0       35.0          168.0  43.1
#
#    Diabetes_Pedigree  Age  Class
# 0              0.627   50      1
# 1              0.351   31      0
# 2              0.672   32      1
# 3              0.167   21      0
# 4              2.288   33      1

# %%
df.describe()
# Out:
#          Pregnant     Glucose  Diastolic_BP   Skin_Fold  Serum_Insulin  \
# count  199.000000  197.000000    191.000000  134.000000      97.000000
# mean     4.201005  119.639594     72.010471   29.582090     151.051546
# std      3.378452   30.557858     13.494244   10.376592     126.811981
# min      0.000000   44.000000     30.000000   10.000000      18.000000
# 25%      1.000000   99.000000     64.000000   22.250000      76.000000
# 50%      4.000000  114.000000     72.000000   29.000000     115.000000
# 75%      7.000000  141.000000     80.000000   36.750000     175.000000
# max     17.000000  197.000000    122.000000   60.000000     846.000000
#
#               BMI  Diabetes_Pedigree         Age       Class
# count  194.000000         199.000000  199.000000  199.000000
# mean    32.661856           0.467136   33.195980    0.371859
# std      7.518240           0.330760   11.028282    0.484520
# min     19.100000           0.084000   21.000000    0.000000
# ...

# %%
numeric_df = df.select_dtypes(include=[np.number])

# %% [markdown]
# Calculating mean,mode,max,range,percentile etc...

# %%
summary_stats = pd.DataFrame({
    'Minimum': numeric_df.min(),
    'Maximum': numeric_df.max(),
    'Mean': numeric_df.mean(),
    'Range': numeric_df.max() - numeric_df.min(),
    'Standard Deviation': numeric_df.std(),
    'Variance': numeric_df.var(),
    '25th Percentile': numeric_df.quantile(0.25),
    '50th Percentile (Median)': numeric_df.quantile(0.50),
    '75th Percentile': numeric_df.quantile(0.75)
})

summary_stats.round(2)

# %%
import pandas as pd

# Given numbers
numbers = [10, 20, 40, 69, 10, 30, 40, 89, 42]

# Create DataFrame
df = pd.DataFrame(numbers, columns=['Values'])

df

# %%
import pandas as pd

numbers = [10, 20, 40, 69, 10, 30, 40, 89, 42]
df = pd.DataFrame(numbers, columns=['Values'])

mean_value = df['Values'].mean()
min_value = df['Values'].min()
max_value = df['Values'].max()
median_value = df['Values'].median()
mode_value = df['Values'].mode().tolist()
variance_value = df['Values'].var()
std_dev_value = df['Values'].std()
range_value = max_value - min_value

results = pd.DataFrame({
    'Statistic': ['Mean', 'Minimum', 'Maximum', 'Median', 'Mode','Variance','Std','Range'],
    'Value': [
        mean_value,
        min_value,
        max_value,
        median_value,
        mode_value,
        variance_value,
        std_dev_value,
        range_value
    ]
})

results

# %%
import pandas as pd

# Take input from user
user_input = input("Enter numbers separated by space: ")

# Convert input string to list of integers
numbers = list(map(int, user_input.split()))

# Create DataFrame
df = pd.DataFrame(numbers, columns=['Values'])

df

# %%
mean_value = df['Values'].mean()
min_value = df['Values'].min()
max_value = df['Values'].max()
median_value = df['Values'].median()
mode_value = df['Values'].mode()
results = pd.DataFrame({
    'Statistic': ['Mean', 'Minimum', 'Maximum', 'Median', 'Mode'],
    'Value': [mean_value, min_value, max_value, median_value, list(mode_value)]
})

results

# %% [markdown]
# # Performing operations uisng user defined functions

# %%
# Mean
def calc_mean(numbers):
    return sum(numbers) / len(numbers)

# Minimum
def calc_min(numbers):
    return min(numbers)

# Maximum
def calc_max(numbers):
    return max(numbers)

# Median
def calc_median(numbers):
    sorted_nums = sorted(numbers)
    n = len(sorted_nums)
    if n % 2 == 0:
        return (sorted_nums[n//2 - 1] + sorted_nums[n//2]) / 2
    else:
        return sorted_nums[n//2]

# Mode
def calc_mode(numbers):
    freq = {}
    for num in numbers:
        freq[num] = freq.get(num, 0) + 1
    max_freq = max(freq.values())
    modes = [k for k, v in freq.items() if v == max_freq]
    return modes  # returns list of modes

# Variance (sample)
def calc_variance(numbers):
    mean = calc_mean(numbers)
    return sum((x - mean)**2 for x in numbers) / (len(numbers) - 1)

# Standard deviation (sample)
def calc_std(numbers):
    return calc_variance(numbers)**0.5

# Range
def calc_range(numbers):
    return calc_max(numbers) - calc_min(numbers)
user_input = input("Enter numbers separated by space: ")
numbers = list(map(int, user_input.split()))
results = {
    'Mean': calc_mean(numbers),
    'Minimum': calc_min(numbers),
    'Maximum': calc_max(numbers),
    'Median': calc_median(numbers),
    'Mode': calc_mode(numbers),
    'Variance': calc_variance(numbers),
    'Standard Deviation': calc_std(numbers),
    'Range': calc_range(numbers)
}


results_df = pd.DataFrame({
    'Statistic': list(results.keys()),
    'Value': list(results.values())
})

results_df

# %% [markdown]
# # 1. Import Libraries & Load Data

# %%
import pandas as pd
import numpy as np

df = pd.read_csv("Coursera.csv")
df.head()

# %% [markdown]
# 2.Check Dataset Information

# %%
df.shape      # Rows & Columns
df.describe()   # Statistical summary

# %% [markdown]
# 3. Detect Missing Values

# %%
df.isnull().sum()

# %% [markdown]
# [link text](https://)4. Handle Missing Values

# %%
df.isnull().sum()

# %% [markdown]
# (a) Drop rows with missing values

# %%
df_drop = df.dropna()

# %% [markdown]
# (b) Fill missing values: All missing values in the Age column are replaced with the mean (average) age.

# %%
for col in df.columns:
    if df[col].dtype != 'object':
        df[col] = df[col].fillna(df[col].mean())

# %% [markdown]
# 5. Remove Duplicate Records
#
# *   List item
# *   List item

# %%
df.drop_duplicates(inplace=True)

# %% [markdown]
# 6. Handle Incorrect Data Types                       df['Date'] → selects the Date column
# pd.to_datetime() → converts data into datetime format (YYYY-MM-DD)
# Handles different date formats automatically (e.g. 12/01/2024, 2024-01-12)
# Replaces the original column with converted values                                               For Salary :                                        df['Salary'] → selects the Salary column
# astype(float) → converts values to decimal (float) numbers
# Removes incorrect data types (like string/object)

# %%
# df['Date'] = pd.to_datetime(df['Date'])
# df['Salary'] = df['Salary'].astype(float)

# %% [markdown]
# 7. Handle Outliers (Using IQR Method)

# %%
Q1 = df['BMI'].quantile(0.25)
Q3 = df['BMI'].quantile(0.75)
IQR = Q3 - Q1

df = df[(df['BMI'] >= Q1 - 1.5 * IQR) &
        (df['BMI'] <= Q3 + 1.5 * IQR)]

# %% [markdown]
# 8. Standardize / Normalize Data

# %%
df['Glucose'] = (df['Glucose'] - df['Glucose'].mean()) / df['Glucose'].std()

# %% [markdown]
# 9. Encode Categorical Data

# %%
# df['Gender'] = df['Gender'].map({'Male': 0, 'Female': 1})

# %% [markdown]
# Label Encoding

# %%
# df['Gender'] = df['Gender'].map({'Male': 0, 'Female': 1})

# %% [markdown]
# One-Hot Encoding

# %%
# df = pd.get_dummies(df, columns=['City'])

# %% [markdown]
# 10. Final Cleaned Dataset

# %%
print(df.head())
df.to_csv("cleaned_diabetes.csv", index=False)

# %%
def mean(values):
    total = 0
    count = 0
    for v in values:
        total += v
        count += 1
    return total / count


def median(values):
    values = sorted(values)
    n = len(values)
    mid = n // 2

    if n % 2 == 0:
        return (values[mid - 1] + values[mid]) / 2
    else:
        return values[mid]


def mode(values):
    freq = {}
    for v in values:
        freq[v] = freq.get(v, 0) + 1

    max_count = max(freq.values())

    modes = [k for k, v in freq.items() if v == max_count]

    if len(modes) == 1:
        return modes[0]
    else:
        return modes


def variance(values):
    m = mean(values)
    total = 0
    count = 0
    for v in values:
        total += (v - m) ** 2
        count += 1
    return total / count


def data_range(values):
    return max(values) - min(values)

# %%
df = pd.read_csv("Diabetes Missing Data (1).csv")

col = "Glucose"

values = df[col].dropna().tolist()


# CALCULATE USING USER-DEFINED FUNCTIONS

print("USER-DEFINED RESULTS:")
print("Mean       :", mean(values))
print("Median     :", median(values))
print("Mode       :", mode(values))
print("Variance   :", variance(values))
print("Range      :", data_range(values))

# VERIFY USING INBUILT FUNCTIONS

print("\nINBUILT FUNCTION RESULTS:")
print("Mean       :", df[col].mean())
print("Median     :", df[col].median())
print("Mode       :", df[col].mode().tolist())
print("Variance   :", df[col].var(ddof=0))
print("Range      :", df[col].max() - df[col].min())

print("\nDESCRIBE OUTPUT:")
df.describe()

# %% [markdown]
# # Illustrate the features distributions using histogram

# %%
import matplotlib.pyplot as plt

# Select only numeric columns
numeric_cols = df.select_dtypes(include=['int64','float64']).columns

# Plot histogram for each numeric feature
df[numeric_cols].hist(bins=20, figsize=(12,10))

# Add title
plt.suptitle("Feature Distributions (Histograms)", fontsize=16)

# Show plots
plt.show()

# %% [markdown]
# # **Data Cleaning**

# %%
import pandas as pd

# Load Dataset
df = pd.read_csv('House Price Prediction Dataset.csv')

print("Dataset Loaded Successfully!")
df.head()

# %%
# Check missing values
print(df.isnull().sum())

# Fill missing numeric values with mean
numeric_cols = df.select_dtypes(include=['int64','float64']).columns
df[numeric_cols] = df[numeric_cols].fillna(df[numeric_cols].mean())

# Fill missing categorical values with mode
categorical_cols = df.select_dtypes(include=['object']).columns
for col in categorical_cols:
    df[col] = df[col].fillna(df[col].mode()[0])

# Remove duplicate rows
df = df.drop_duplicates()

print("Data Cleaning Completed")

# %% [markdown]
# # **Data Integration**

# %%
extra_data = pd.DataFrame({
    'Id': df['Id'].head(100),
    'OwnerType': ['Private']*100
})

df = pd.merge(df, extra_data, on='Id', how='left')

print("Data Integration Completed")

# %% [markdown]
# # **Data Transformation**

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler

# Label Encoding categorical columns
categorical_cols = df.select_dtypes(include=['object']).columns

for col in categorical_cols:
    le = LabelEncoder()
    df[col] = le.fit_transform(df[col])

# Feature Scaling
numeric_cols = df.select_dtypes(include=['int64','float64']).columns
scaler = StandardScaler()
df[numeric_cols] = scaler.fit_transform(df[numeric_cols])

print("Data Transformation Completed")

# %% [markdown]
# # **Data Model Building**

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score, classification_report

# Create Target Column (High Price / Low Price)
df['PriceCategory'] = (df['Price'] > df['Price'].median()).astype(int)

# Features and Target
X = df.drop(['Price','PriceCategory'], axis=1)
y = df['PriceCategory']

# Split data
X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42)

# Train Model
model = LogisticRegression(max_iter=1000)
model.fit(X_train, y_train)

# Predictions
y_pred = model.predict(X_test)

# Evaluation
print("Accuracy:", accuracy_score(y_test, y_pred))
print(classification_report(y_test, y_pred))
